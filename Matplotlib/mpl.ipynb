# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
price = [48000,49000,58000,46000,42000,8500000]
year = [2012,2012,2014,2015,2016,2017]

plt.plot(year,price)
plt.ylim(0,80000)

plt.grid()

# %%
batsman = pd.read_csv('sharma-kohli.csv')
batsman

plt.plot(batsman['index'],batsman['V Kohli'])

# %%
plt.plot(batsman['index'],batsman['V Kohli'],label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='red',linestyle='dashed',marker='o',label='Rohit')

plt.title('Rohit vs Kohli Career Comparison')

plt.ylabel('scored runs')
plt.xlabel('year')

plt.legend()
