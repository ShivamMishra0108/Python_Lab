# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig = plt.figure()

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)

z = xx**2 + yy**2
z.shape

ax = plt.subplot()

p = ax.contour(xx,yy,z,cmap='viridis')
fig.colorbar(p)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13908\4068943193.py:12: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 2 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   fig.colorbar(p)

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)

z = xx**2 + yy**2
z.shape

ax = plt.subplot()

p = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13908\2765051436.py:12: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 2 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   fig.colorbar(p)

# %%
z = np.cos(xx) + np.cos(yy)
z.shape

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13908\2227742238.py:7: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 2 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   fig.colorbar(p)

# %%
z = np.cos(xx) + np.cos(yy)
z.shape

ax = plt.subplot()

p = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13908\1041940304.py:7: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 2 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   fig.colorbar(p)
