# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
subjects = ['maths','sst','english','hindi','science']
marks = [92,70,82,83,86]

plt.pie(marks,labels=subjects,autopct='%0.1f%%',shadow=True,explode=[0.2,0,0,0,0])


# TO SAVE THE GRAPH:

plt.savefig('PieChart.png')
