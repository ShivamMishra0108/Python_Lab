# %%
import pandas as pd

country= ['India',"USA","Nepal","canada"]

pd.Series(country)
# Out:
# 0     India
# 1       USA
# 2     Nepal
# 3    canada
# dtype: object

# %%
import pandas as pd

marks = [45,67,84,56]

subject = ["hindi","english","maths","science"]

pd.Series(marks,index=subject,name="Shivam ke marks")
# Out:
# hindi      45
# english    67
# maths      84
# science    56
# Name: Shivam ke marks, dtype: int64

# %%
marks = {
    'maths':78,
    'english':78,
    'hindi':78,
    'science':78
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths      78
# english    78
# hindi      78
# science    78
# dtype: int64

# %%
marks_series.size
marks_series.name
marks_series.is_unique
marks_series.index
# Out:
# Index(['maths', 'english', 'hindi', 'science'], dtype='object')
